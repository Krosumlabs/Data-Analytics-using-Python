# %%
import pandas as pd

# %%
df1 = pd.read_csv('E:\\emp.csv')
df1
# Out:
#    eid  ename  edept     eplace  ecost
# 0  101    raj  sales       pune   1000
# 1  102    leo   prod     bglore   2000
# 2  103   paul     HR    chennai   3000
# 3  104    anu     hr  hyderabad   4000
# 4  456  kumar  sales     bglore   3000
# 5  105   zion     Hr     mumbai   5000
# 6  106   bibu  sales     bglore   1450
# 7  107  theeb  sales      noida   4590
# 8  108   bibu  sales     bglore   5000
# 9  113  kumar   prod  hyderabad   5423

# %%
d={'K1':[10,20,30],'K2':[11,12,13]}


pd.DataFrame(d)
# Out:
#    K1  K2
# 0  10  11
# 1  20  12
# 2  30  13

# %%
df2 = pd.DataFrame(d)
df2.columns
# Out:
# Index(['K1', 'K2'], dtype='object')

# %%
df2['K3']=[15,25,35] # Add new data to an existing dataframe -like dict
df2
# Out:
#    K1  K2  K3
# 0  10  11  15
# 1  20  12  25
# 2  30  13  35

# %%
df2
# Out:
#    K1  K2  K3
# 0  10  11  15
# 1  20  12  25
# 2  30  13  35

# %%
# remove any specific columns
df2.drop('K2',axis='columns')
# Out:
#    K1  K3
# 0  10  15
# 1  20  25
# 2  30  35

# %%
df2
# Out:
#    K1  K2  K3
# 0  10  11  15
# 1  20  12  25
# 2  30  13  35

# %%
# remove any specific columns
df2.drop('K2',axis='columns',inplace=True) 
# <or>
# df2.drop('K2',axis=1,inplace=True)

# %%
df2
# Out:
#    K1  K3
# 0  10  15
# 1  20  25
# 2  30  35

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df2.drop(1) # remove 1st index
# Out:
#    K1  K3
# 0  10  15
# 2  30  35

# %%
df2.drop(1,axis='index') # <or> df2.drop(1,axis=0)
# Out:
#    K1  K3
# 0  10  15
# 2  30  35

# %%
df2
# Out:
#    K1  K3
# 0  10  15
# 1  20  25
# 2  30  35

# %%
df2.drop(1,axis='index',inplace=True) # <or> df2.drop(1,axis=0,inplace=True)

# %%
df2
# Out:
#    K1  K3
# 0  10  15
# 2  30  35

# %%
pd.read_csv('E:\\emp.csv')
# Out:
#    eid  ename  edept     eplace  ecost
# 0  101    raj  sales       pune   1000
# 1  102    leo   prod     bglore   2000
# 2  103   paul     HR    chennai   3000
# 3  104    anu     hr  hyderabad   4000
# 4  456  kumar  sales     bglore   3000
# 5  105   zion     Hr     mumbai   5000
# 6  106   bibu  sales     bglore   1450
# 7  107  theeb  sales      noida   4590
# 8  108   bibu  sales     bglore   5000
# 9  113  kumar   prod  hyderabad   5423

# %%
import json

# %%
d={}
d['Type']=['eth0','eth1','eth2']
d['IP']=['10.20.30.40','11.23.45.45','10.20.34.55']
d['port']=[3000,4000,5000]
d['app']=['gl','fl','pm']

wobj = open('E:\\test.json','w')
json.dump(d,wobj)
wobj.close()

# %%
pd.read_json('E:\\test.json')
# Out:
#    Type           IP  port app
# 0  eth0  10.20.30.40  3000  gl
# 1  eth1  11.23.45.45  4000  fl
# 2  eth2  10.20.34.55  5000  pm

# %%
df3 = pd.read_json('E:\\test.json')
df3.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df3.columns
# Out:
# Index(['Type', 'IP', 'port', 'app'], dtype='object')

# %%
df3['Type']
# Out:
# 0    eth0
# 1    eth1
# 2    eth2
# Name: Type, dtype: object

# %%
import requests

# %%
def download_url(url):
    r=requests.get(url)
    if(r.status_code != 200):
        print('url download is failed')
        return False
    if('application/json' in r.headers['Content-Type']):
        jd = r.text
        python_data = json.loads(jd) # convert to python
        return python_data

# %%
pd.DataFrame(download_url('https://api.github.com/users/hadley/orgs'))
# Out:
#                login        id                           node_id  \
# 0              ggobi    423638  MDEyOk9yZ2FuaXphdGlvbjQyMzYzOA==
# 1            rstudio    513560  MDEyOk9yZ2FuaXphdGlvbjUxMzU2MA==
# 2             rstats    722735  MDEyOk9yZ2FuaXphdGlvbjcyMjczNQ==
# 3           ropensci   1200269  MDEyOk9yZ2FuaXphdGlvbjEyMDAyNjk=
# 4           rjournal   3330561  MDEyOk9yZ2FuaXphdGlvbjMzMzA1NjE=
# 5              r-dbi   5695665  MDEyOk9yZ2FuaXphdGlvbjU2OTU2NjU=
# 6        RConsortium  15366137  MDEyOk9yZ2FuaXphdGlvbjE1MzY2MTM3
# 7          tidyverse  22032646  MDEyOk9yZ2FuaXphdGlvbjIyMDMyNjQ2
# 8              r-lib  22618716  MDEyOk9yZ2FuaXphdGlvbjIyNjE4NzE2
# 9  rstudio-education  34165516  MDEyOk9yZ2FuaXphdGlvbjM0MTY1NTE2
#
#                                              url  \
# 0              https://api.github.com/orgs/ggobi
# 1            https://api.github.com/orgs/rstudio
# 2             https://api.github.com/orgs/rstats
# 3           https://api.github.com/orgs/ropensci
# ...

# %%
df4 = pd.DataFrame(download_url('https://api.github.com/users/hadley/orgs'))

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   login               10 non-null     object
#  1   id                  10 non-null     int64
#  2   node_id             10 non-null     object
#  3   url                 10 non-null     object
#  4   repos_url           10 non-null     object
#  5   events_url          10 non-null     object
#  6   hooks_url           10 non-null     object
#  7   issues_url          10 non-null     object
#  8   members_url         10 non-null     object
#  9   public_members_url  10 non-null     object
#  10  avatar_url          10 non-null     object
#  11  description         8 non-null      object
# dtypes: int64(1), object(11)
# memory usage: 1.1+ KB

# %%
df4.columns
# Out:
# Index(['login', 'id', 'node_id', 'url', 'repos_url', 'events_url', 'hooks_url',
#        'issues_url', 'members_url', 'public_members_url', 'avatar_url',
#        'description'],
#       dtype='object')

# %%
df4.shape
# Out:
# (10, 12)

# %%
# df4.drop('node_id',axis=1) <== to remove single column
#
#    Vs 
df4.drop(['repos_url','events_url','issues_url','members_url','description'],axis=1)
# Out:
#                login        id                           node_id  \
# 0              ggobi    423638  MDEyOk9yZ2FuaXphdGlvbjQyMzYzOA==
# 1            rstudio    513560  MDEyOk9yZ2FuaXphdGlvbjUxMzU2MA==
# 2             rstats    722735  MDEyOk9yZ2FuaXphdGlvbjcyMjczNQ==
# 3           ropensci   1200269  MDEyOk9yZ2FuaXphdGlvbjEyMDAyNjk=
# 4           rjournal   3330561  MDEyOk9yZ2FuaXphdGlvbjMzMzA1NjE=
# 5              r-dbi   5695665  MDEyOk9yZ2FuaXphdGlvbjU2OTU2NjU=
# 6        RConsortium  15366137  MDEyOk9yZ2FuaXphdGlvbjE1MzY2MTM3
# 7          tidyverse  22032646  MDEyOk9yZ2FuaXphdGlvbjIyMDMyNjQ2
# 8              r-lib  22618716  MDEyOk9yZ2FuaXphdGlvbjIyNjE4NzE2
# 9  rstudio-education  34165516  MDEyOk9yZ2FuaXphdGlvbjM0MTY1NTE2
#
#                                              url  \
# 0              https://api.github.com/orgs/ggobi
# 1            https://api.github.com/orgs/rstudio
# 2             https://api.github.com/orgs/rstats
# 3           https://api.github.com/orgs/ropensci
# ...

# %%
# df4.drop('node_id',axis=1) <== to remove single column
#
#    Vs 
df4.drop(['repos_url','events_url','issues_url','members_url','description'],
         axis=1,inplace=True)

# %%
df4.shape
# Out:
# (10, 7)

# %%
df4.drop(index=[3,6,8,9],axis=0,inplace=True)

# %%
df4.shape
# Out:
# (6, 7)

# %%
df4
# Out:
#        login        id                           node_id  \
# 0      ggobi    423638  MDEyOk9yZ2FuaXphdGlvbjQyMzYzOA==
# 1    rstudio    513560  MDEyOk9yZ2FuaXphdGlvbjUxMzU2MA==
# 2     rstats    722735  MDEyOk9yZ2FuaXphdGlvbjcyMjczNQ==
# 4   rjournal   3330561  MDEyOk9yZ2FuaXphdGlvbjMzMzA1NjE=
# 5      r-dbi   5695665  MDEyOk9yZ2FuaXphdGlvbjU2OTU2NjU=
# 7  tidyverse  22032646  MDEyOk9yZ2FuaXphdGlvbjIyMDMyNjQ2
#
#                                      url  \
# 0      https://api.github.com/orgs/ggobi
# 1    https://api.github.com/orgs/rstudio
# 2     https://api.github.com/orgs/rstats
# 4   https://api.github.com/orgs/rjournal
# 5      https://api.github.com/orgs/r-dbi
# 7  https://api.github.com/orgs/tidyverse
#
#                                      hooks_url  \
# 0      https://api.github.com/orgs/ggobi/hooks
# 1    https://api.github.com/orgs/rstudio/hooks
# 2     https://api.github.com/orgs/rstats/hooks
# 4   https://api.github.com/orgs/rjournal/hooks
# ...

# %%
# dataframe ->write to file <or> convert to another format
#                   pd.to_
#                   pd.read_
#
import sys

# %%
df4.to_csv(sys.stdout)
# Out:
# ,login,id,node_id,url,hooks_url,public_members_url,avatar_url
# 0,ggobi,423638,MDEyOk9yZ2FuaXphdGlvbjQyMzYzOA==,https://api.github.com/orgs/ggobi,https://api.github.com/orgs/ggobi/hooks,https://api.github.com/orgs/ggobi/public_members{/member},https://avatars.githubusercontent.com/u/423638?v=4
# 1,rstudio,513560,MDEyOk9yZ2FuaXphdGlvbjUxMzU2MA==,https://api.github.com/orgs/rstudio,https://api.github.com/orgs/rstudio/hooks,https://api.github.com/orgs/rstudio/public_members{/member},https://avatars.githubusercontent.com/u/513560?v=4
# 2,rstats,722735,MDEyOk9yZ2FuaXphdGlvbjcyMjczNQ==,https://api.github.com/orgs/rstats,https://api.github.com/orgs/rstats/hooks,https://api.github.com/orgs/rstats/public_members{/member},https://avatars.githubusercontent.com/u/722735?v=4
# ...

# %%
df3
# Out:
#    Type           IP  port app
# 0  eth0  10.20.30.40  3000  gl
# 1  eth1  11.23.45.45  4000  fl
# 2  eth2  10.20.34.55  5000  pm

# %%
df3.to_csv(sys.stdout)
# Out:
# ,Type,IP,port,app
# 0,eth0,10.20.30.40,3000,gl
# 1,eth1,11.23.45.45,4000,fl
# 2,eth2,10.20.34.55,5000,pm

# %%
df4.to_csv('E:\\test1.csv')

# %%
pd.read_csv('E:\\test1.csv')
# Out:
#    Unnamed: 0      login        id                           node_id  \
# 0           0      ggobi    423638  MDEyOk9yZ2FuaXphdGlvbjQyMzYzOA==
# 1           1    rstudio    513560  MDEyOk9yZ2FuaXphdGlvbjUxMzU2MA==
# 2           2     rstats    722735  MDEyOk9yZ2FuaXphdGlvbjcyMjczNQ==
# 3           4   rjournal   3330561  MDEyOk9yZ2FuaXphdGlvbjMzMzA1NjE=
# 4           5      r-dbi   5695665  MDEyOk9yZ2FuaXphdGlvbjU2OTU2NjU=
# 5           7  tidyverse  22032646  MDEyOk9yZ2FuaXphdGlvbjIyMDMyNjQ2
#
#                                      url  \
# 0      https://api.github.com/orgs/ggobi
# 1    https://api.github.com/orgs/rstudio
# 2     https://api.github.com/orgs/rstats
# 3   https://api.github.com/orgs/rjournal
# 4      https://api.github.com/orgs/r-dbi
# 5  https://api.github.com/orgs/tidyverse
#
#                                      hooks_url  \
# 0      https://api.github.com/orgs/ggobi/hooks
# 1    https://api.github.com/orgs/rstudio/hooks
# ...

# %%
df5= pd.read_csv('E:\\test1.csv')
df5.columns
# Out:
# Index(['Unnamed: 0', 'login', 'id', 'node_id', 'url', 'hooks_url',
#        'public_members_url', 'avatar_url'],
#       dtype='object')

# %%
df5.drop(columns=['Unnamed: 0','hooks_url'],axis=1,inplace=True)

# %%
df5.columns
# Out:
# Index(['login', 'id', 'node_id', 'url', 'public_members_url', 'avatar_url'], dtype='object')

# %%
df5.rename({'public_members_url':'public'},axis=1)
# Out:
#        login        id                           node_id  \
# 0      ggobi    423638  MDEyOk9yZ2FuaXphdGlvbjQyMzYzOA==
# 1    rstudio    513560  MDEyOk9yZ2FuaXphdGlvbjUxMzU2MA==
# 2     rstats    722735  MDEyOk9yZ2FuaXphdGlvbjcyMjczNQ==
# 3   rjournal   3330561  MDEyOk9yZ2FuaXphdGlvbjMzMzA1NjE=
# 4      r-dbi   5695665  MDEyOk9yZ2FuaXphdGlvbjU2OTU2NjU=
# 5  tidyverse  22032646  MDEyOk9yZ2FuaXphdGlvbjIyMDMyNjQ2
#
#                                      url  \
# 0      https://api.github.com/orgs/ggobi
# 1    https://api.github.com/orgs/rstudio
# 2     https://api.github.com/orgs/rstats
# 3   https://api.github.com/orgs/rjournal
# 4      https://api.github.com/orgs/r-dbi
# 5  https://api.github.com/orgs/tidyverse
#
#                                               public  \
# 0  https://api.github.com/orgs/ggobi/public_membe...
# 1  https://api.github.com/orgs/rstudio/public_mem...
# 2  https://api.github.com/orgs/rstats/public_memb...
# ...

# %%
df5.rename({'public_members_url':'public'},axis=1,inplace=True)

# %%
df5.columns
# Out:
# Index(['login', 'id', 'node_id', 'url', 'public', 'avatar_url'], dtype='object')

# %%
df5.to_csv(sys.stdout)
# Out:
# ,login,id,node_id,url,public,avatar_url
# 0,ggobi,423638,MDEyOk9yZ2FuaXphdGlvbjQyMzYzOA==,https://api.github.com/orgs/ggobi,https://api.github.com/orgs/ggobi/public_members{/member},https://avatars.githubusercontent.com/u/423638?v=4
# 1,rstudio,513560,MDEyOk9yZ2FuaXphdGlvbjUxMzU2MA==,https://api.github.com/orgs/rstudio,https://api.github.com/orgs/rstudio/public_members{/member},https://avatars.githubusercontent.com/u/513560?v=4
# 2,rstats,722735,MDEyOk9yZ2FuaXphdGlvbjcyMjczNQ==,https://api.github.com/orgs/rstats,https://api.github.com/orgs/rstats/public_members{/member},https://avatars.githubusercontent.com/u/722735?v=4
# 3,rjournal,3330561,MDEyOk9yZ2FuaXphdGlvbjMzMzA1NjE=,https://api.github.com/orgs/rjournal,https://api.github.com/orgs/rjournal/public_members{/member},https://avatars.githubusercontent.com/u/3330561?v=4
# ...

# %%
df5.to_csv(sys.stdout,sep="|") # Vs pd.read_csv('filename',sep='|')
# Out:
# |login|id|node_id|url|public|avatar_url
# 0|ggobi|423638|MDEyOk9yZ2FuaXphdGlvbjQyMzYzOA==|https://api.github.com/orgs/ggobi|https://api.github.com/orgs/ggobi/public_members{/member}|https://avatars.githubusercontent.com/u/423638?v=4
# 1|rstudio|513560|MDEyOk9yZ2FuaXphdGlvbjUxMzU2MA==|https://api.github.com/orgs/rstudio|https://api.github.com/orgs/rstudio/public_members{/member}|https://avatars.githubusercontent.com/u/513560?v=4
# 2|rstats|722735|MDEyOk9yZ2FuaXphdGlvbjcyMjczNQ==|https://api.github.com/orgs/rstats|https://api.github.com/orgs/rstats/public_members{/member}|https://avatars.githubusercontent.com/u/722735?v=4
# 3|rjournal|3330561|MDEyOk9yZ2FuaXphdGlvbjMzMzA1NjE=|https://api.github.com/orgs/rjournal|https://api.github.com/orgs/rjournal/public_members{/member}|https://avatars.githubusercontent.com/u/3330561?v=4
# ...

# %%
df5.to_csv(sys.stdout,columns=['node_id','url'])
# Out:
# ,node_id,url
# 0,MDEyOk9yZ2FuaXphdGlvbjQyMzYzOA==,https://api.github.com/orgs/ggobi
# 1,MDEyOk9yZ2FuaXphdGlvbjUxMzU2MA==,https://api.github.com/orgs/rstudio
# 2,MDEyOk9yZ2FuaXphdGlvbjcyMjczNQ==,https://api.github.com/orgs/rstats
# 3,MDEyOk9yZ2FuaXphdGlvbjMzMzA1NjE=,https://api.github.com/orgs/rjournal
# 4,MDEyOk9yZ2FuaXphdGlvbjU2OTU2NjU=,https://api.github.com/orgs/r-dbi
# 5,MDEyOk9yZ2FuaXphdGlvbjIyMDMyNjQ2,https://api.github.com/orgs/tidyverse

# %%
pd.read_excel('E:\\course.xlsx')
# Out:
#     Course   Fees  Duration     Tutor
# 0        C  25000        24    Mr.Tom
# 1      C++  26000        22    Ms.Anu
# 2     Java  30000        30   Mr.Shiv
# 3     html   5000         3  Ms.Theeb
# 4   python  15000        10    Mr.Raj
# 5     ruby  13000        20    Mr.Tom
# 6       ML  23000        30    Ms.Anu
# 7    Mysql  10000        12   Mr.Shiv
# 8   Oracle   9000        10    Mr.Leo
# 9       DA  12300        15    Ms.Anj
# 10      AI  34000        30    Ms.Anu

# %%
df5.to_excel('E:\\test1.xlsx')

# %%
#df5.to_excel('E:\\test3.xls') ->Error

# %%
pd.read_excel('E:\\course.xlsx')
# Out:
#     Course   Fees  Duration     Tutor
# 0        C  25000        24    Mr.Tom
# 1      C++  26000        22    Ms.Anu
# 2     Java  30000        30   Mr.Shiv
# 3     html   5000         3  Ms.Theeb
# 4   python  15000        10    Mr.Raj
# 5     ruby  13000        20    Mr.Tom
# 6       ML  23000        30    Ms.Anu
# 7    Mysql  10000        12   Mr.Shiv
# 8   Oracle   9000        10    Mr.Leo
# 9       DA  12300        15    Ms.Anj
# 10      AI  34000        30    Ms.Anu

# %%
pd.read_excel('E:\\course.xlsx')
# Out:
#     Course   Fees  Duration     Tutor
# 0        C  25000        24    Mr.Tom
# 1      C++  26000        22    Ms.Anu
# 2     Java  30000        30   Mr.Shiv
# 3     html   5000         3  Ms.Theeb
# 4   python  15000        10    Mr.Raj
# 5     ruby  13000        20    Mr.Tom
# 6       ML  23000        30    Ms.Anu
# 7    Mysql  10000        12   Mr.Shiv
# 8   Oracle   9000        10    Mr.Leo
# 9       DA  12300        15    Ms.Anj
# 10      AI  34000        30    Ms.Anu

# %%
pd.read_excel('E:\\course.xlsx',sheet_name='products')
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0         NaN    product      price
# 1         NaN      prodA       1000
# 2         NaN      prodB       2000
# 3         NaN      prodC       3000
# 4         NaN      prodD       3000
# 5         NaN      prodA       1234
# 6         NaN      prodB       6000
# 7         NaN      prodE       5412
# 8         NaN      prodB       8000

# %%
pd.read_excel('E:\\course.xlsx',sheet_name=['One','products'])
# Out:
# {'One':     Course   Fees  Duration     Tutor
#  0        C  25000        24    Mr.Tom
#  1      C++  26000        22    Ms.Anu
#  2     Java  30000        30   Mr.Shiv
#  3     html   5000         3  Ms.Theeb
#  4   python  15000        10    Mr.Raj
#  5     ruby  13000        20    Mr.Tom
#  6       ML  23000        30    Ms.Anu
#  7    Mysql  10000        12   Mr.Shiv
#  8   Oracle   9000        10    Mr.Leo
#  9       DA  12300        15    Ms.Anj
#  10      AI  34000        30    Ms.Anu,
#  'products':    Unnamed: 0 Unnamed: 1 Unnamed: 2
#  0         NaN    product      price
#  1         NaN      prodA       1000
#  2         NaN      prodB       2000
#  3         NaN      prodC       3000
#  4         NaN      prodD       3000
#  5         NaN      prodA       1234
#  6         NaN      prodB       6000
#  7         NaN      prodE       5412
#  8         NaN      prodB       8000}

# %%
df6 = pd.read_excel('E:\\course.xlsx',sheet_name=['One','products'])
df6['One']
# Out:
#     Course   Fees  Duration     Tutor
# 0        C  25000        24    Mr.Tom
# 1      C++  26000        22    Ms.Anu
# 2     Java  30000        30   Mr.Shiv
# 3     html   5000         3  Ms.Theeb
# 4   python  15000        10    Mr.Raj
# 5     ruby  13000        20    Mr.Tom
# 6       ML  23000        30    Ms.Anu
# 7    Mysql  10000        12   Mr.Shiv
# 8   Oracle   9000        10    Mr.Leo
# 9       DA  12300        15    Ms.Anj
# 10      AI  34000        30    Ms.Anu

# %%
df6['products']
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0         NaN    product      price
# 1         NaN      prodA       1000
# 2         NaN      prodB       2000
# 3         NaN      prodC       3000
# 4         NaN      prodD       3000
# 5         NaN      prodA       1234
# 6         NaN      prodB       6000
# 7         NaN      prodE       5412
# 8         NaN      prodB       8000

# %%
#excel_df = pd.read_excel('E:\\test1.xlsx')
#          Vs
xl_df = pd.ExcelFile('E:\\course.xlsx')
xl_df.sheet_names # To get list of sheets from excel file
# Out:
# ['One', 'products']

# %%
pd.read_excel(xl_df,'One') # read a particular sheet name
# Out:
#     Course   Fees  Duration     Tutor
# 0        C  25000        24    Mr.Tom
# 1      C++  26000        22    Ms.Anu
# 2     Java  30000        30   Mr.Shiv
# 3     html   5000         3  Ms.Theeb
# 4   python  15000        10    Mr.Raj
# 5     ruby  13000        20    Mr.Tom
# 6       ML  23000        30    Ms.Anu
# 7    Mysql  10000        12   Mr.Shiv
# 8   Oracle   9000        10    Mr.Leo
# 9       DA  12300        15    Ms.Anj
# 10      AI  34000        30    Ms.Anu

# %%
import sqlite3

# %%
sqlite3.connect('mydb\products.db')

# %%
conn = sqlite3.connect('mydb\products.db')
pd.read_sql_query('select *from prod',conn)
# Out:
#     id  pname  pcost
# 0  101  prodA   1000
# 1  102  prodB   2000
# 2  103  prodC   3000
# 3  104  prodD   4000
# 4  105  prodE   5000

# %%
df7 = pd.read_sql_query('select *from prod',conn)
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      5 non-null      int64
#  1   pname   5 non-null      object
#  2   pcost   5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
df7.to_excel('E:\\mydb.xlsx') # write to Excel file

# %%
# To access word document
#
# pip instll python-docx

# !pip install python-docx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for python-docx from https://files.pythonhosted.org/packages/3e/3d/330d9efbdb816d3f60bf2ad92f05e1708e4a1b9abe80461ac3444c83f749/python_docx-1.1.2-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/244.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/244.3 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/244.3 kB 653.6 kB/s eta 0:00:01
#    ------------------ --------------------- 112.6/244.3 kB 1.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 174.1/244.3 kB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 235.5/244.3 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 244.3/244.3 kB 1.2 MB/s eta 0:00:00
# ...

# %%
import docx

# %%
print(docx.Document)
# Out:
# <function Document at 0x000001C2E57B1F80>

# %%
docx.Document('E:\\Activity-1.docx')

# %%
doc_obj = docx.Document('E:\\Activity-1.docx')
doc_obj.paragraphs

# %%
doc_obj = docx.Document('E:\\Activity-1.docx')

for var in doc_obj.paragraphs:
    print(var.text)
# Out:
# Q1. Write a C++ program to check overflow/underflow during various arithmetic operations.
# Sample Output:
# Check overflow/underflow during various arithmetical operation:
#
# Range of int is [-2147483648, 2147483647]
# Overflow the integer range and set in minimum range: -2147483648
# Increasing from its minimum range: -2147483647
# Product is :1
# Underflow the range and set in maximum range: 2147483647
# Decreasing from its maximum range: 2147483646
# Product is: 0
#
#
# Q2. Write a program in C++ that converts kilometers per hour to miles per hour.
# Sample Output:
# Convert kilometers per hour to miles per hour :
# ----------------------------------------------------
# Input the distance in kilometer : 25
# The 25 Km./hr. means 15.5343 Miles/hr.
#
#
#
#
# Q3. Write a program in C++ to convert temperature in Kelvin to Fahrenheit.
#
#
#
#
#
#
# Q4. Write C++ Program do following task
# Largest of 3 nos using conditional op
# Largest of 2 nos without branching
# ...

# %%
doc_obj = docx.Document('E:\\Activity-1.docx')

for var in doc_obj.paragraphs:
    if 'range' in var.text:
        print(var.text)
# Out:
# Overflow the integer range and set in minimum range: -2147483648
# Increasing from its minimum range: -2147483647
# Product is :1
# Underflow the range and set in maximum range: 2147483647
# Decreasing from its maximum range: 2147483646
# Product is: 0

# %%
L=[]
doc_obj = docx.Document('E:\\Activity-1.docx')

for var in doc_obj.paragraphs:
    if 'range' in var.text:
        L.append(var.text)

# %%
d={}
d['range']=L
d
# Out:
# {'range': ['Overflow the integer range and set in minimum range: -2147483648\nIncreasing from its minimum range: -2147483647\nProduct is :1\nUnderflow the range and set in maximum range: 2147483647\nDecreasing from its maximum range: 2147483646\nProduct is: 0']}

# %%
pd.DataFrame(d)
# Out:
#                                                range
# 0  Overflow the integer range and set in minimum ...

# %%
pd.DataFrame(d).info()
pd.DataFrame(d).shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   range   1 non-null      object
# dtypes: object(1)
# memory usage: 140.0+ bytes
# (1, 1)

# %%
doc_obj = docx.Document('E:\\Test Cases.docx')

# %%
for var in doc_obj.paragraphs:
    print(var.text)
# Out:
# << template information >>
# << This document is a template. It contains text that does not have to be in accordance of the situation at hand. The instructions should be deleted in any case (the blue text within the << and >> signs).
#
# There is also text between single hooks (<Text>). This text contains example elaboration and also needs to be removed or replaced by the definitive text. All other standard text may be adjusted as need fits.
#
# The sub-chapters (chapters en paragraphs) are obligatorily. That means; when a certain aspect is not paid attention to, you have explain this decision.
#
# A template  risk assessment is available. If needed this template can be transferred to this release advice.>>
#
#
# Version information
#
# Distribution list
#
#
# Approval Client
# << Optional: the approval of the client can be represented here. In that case the signed hardcopy needs to be archived. >>
#
# Management summary
#
# Table of contents
# 1	Introduction	1
# ...

# %%
doc_obj.core_properties.keywords
# Out:
# 'v2.00'

# %%
doc_obj.core_properties.comments
# Out:
# ''

# %%
import re

# %%
doc_obj = docx.Document('E:\\Test Cases.docx')

test_scenarios_start = None
test_case_info = []
current_scenarios = {}
for var in doc_obj.paragraphs:
    if re.search('4.4.*Test Scenarios',var.text):
        test_scenarios_start = True
        continue
    # after finiding this pattern we begin extract test case details
    if test_scenarios_start:
        if var.text.strip() == '':
            if current_scenarios:
                test_case_info.appen(current_scenarios)
                current_scenarios = {} # reset for next test case
        else:
            if re.search('Test Flow 1.*',var.text):
                print(var.text.strip())
# Out:
# 4.4.1	Test Flow 1	8
# Test Flow 1

# %%
xl_obj = pd.ExcelFile('E:\\testcase.xlsx')
sheet_name = xl_obj.sheet_names
xl_df = pd.read_excel(xl_obj,sheet_name)
xl_df['Sheet1']
# Out:
#                       Slno                                     Navigation  \
# 0   4.4.1.1.1.                                         Login: mfg/welcome
# 1                      NaN  Resp:  Manufacturing and Distribution Manager
# 2                      NaN              Inventory->Kanban->Pull Sequences
# 3                      NaN                                            NaN
# 4                      NaN                                            NaN
# 5                      NaN                                            NaN
# 6                      NaN                                            NaN
# 7                      NaN                                            NaN
# 8                      NaN                                            NaN
# 9                      NaN                                            NaN
# 10                     NaN                                            NaN
# 11                     NaN                                            NaN
# ...

# %%
d={'K1':[10,20,20],'K2':[20,20,20],'K3':[20,20,20]}
pd.DataFrame(d)
# Out:
#    K1  K2  K3
# 0  10  20  20
# 1  20  20  20
# 2  20  20  20

# %%
df8 = pd.DataFrame(d)
df8.duplicated() # Test any duplicate details is exists
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   K1      3 non-null      int64
#  1   K2      3 non-null      int64
#  2   K3      3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0 bytes

# %%
df8.duplicated().sum() # Count no.of duplicate items
# Out:
# 1

# %%
df8.duplicated().any() # returns bool ->True <== there is duplicate items exists
# Out:
# True

# %%
df8.drop_duplicates() # drop duplicate items
# Out:
#    K1  K2  K3
# 0  10  20  20
# 1  20  20  20

# %%
df8
# Out:
#    K1  K2  K3
# 0  10  20  20
# 1  20  20  20
# 2  20  20  20

# %%
df8.drop_duplicates(inplace=True)

# %%
df8
# Out:
#    K1  K2  K3
# 0  10  20  20
# 1  20  20  20

# %%
df8.duplicated().sum() # ->0 There is no duplicate item
# Out:
# 0

# %%
df8.duplicated().any() # ->False - There is no duplicate item
# Out:
# False

# %%
xl_df['Sheet1'].duplicated().any()
# Out:
# True

# %%
xl_df['Sheet1'].duplicated().sum()
# Out:
# 2

# %%
xl_df['Sheet1'].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# dtype: bool

# %%
xl_df['Sheet1'].drop_duplicates(inplace=True)

# %%
xl_df['Sheet1'].duplicated().sum()
# Out:
# 0

# %%
import numpy as np
d={'K1':[10,np.nan,30],'K2':[20,np.nan,np.nan],'K3':[np.nan,None,np.nan]}
d['K4']=[1,2,3]
pd.DataFrame(d)
# Out:
#      K1    K2  K3  K4
# 0  10.0  20.0 NaN   1
# 1   NaN   NaN NaN   2
# 2  30.0   NaN NaN   3

# %%
df9 = pd.DataFrame(d)

# To determine any null(NaN) value is present
df9.isnull() # ->True - NaN value is exists
# Out:
#       K1     K2    K3     K4
# 0  False  False  True  False
# 1   True   True  True  False
# 2  False   True  True  False

# %%
df9.isnull().any() # ->True - NaN value is exists
# Out:
# K1     True
# K2     True
# K3     True
# K4    False
# dtype: bool

# %%
df9.isnull().sum() # Each Column based - display NaN value count
# Out:
# K1    1
# K2    2
# K3    3
# K4    0
# dtype: int64

# %%
df9.isna() # same as df9.isnull()
# Out:
#       K1     K2    K3     K4
# 0  False  False  True  False
# 1   True   True  True  False
# 2  False   True  True  False

# %%
print(df9.isna().sum(),"\n\n",df9.isna().any())
# Out:
# K1    1
# K2    2
# K3    3
# K4    0
# dtype: int64
#
#  K1     True
# K2     True
# K3     True
# K4    False
# dtype: bool

# %%
# How to replace NaN value ?
# fillna(value=<replaceValue>)

df9
# Out:
#      K1    K2  K3  K4
# 0  10.0  20.0 NaN   1
# 1   NaN   NaN NaN   2
# 2  30.0   NaN NaN   3

# %%
df9.fillna('DATA')
# Out:
#      K1    K2    K3  K4
# 0  10.0  20.0  DATA   1
# 1  DATA  DATA  DATA   2
# 2  30.0  DATA  DATA   3

# %%
df9.fillna(56)
# Out:
#      K1    K2    K3  K4
# 0  10.0  20.0  56.0   1
# 1  56.0  56.0  56.0   2
# 2  30.0  56.0  56.0   3

# %%
df9.fillna(value=56)
# Out:
#      K1    K2    K3  K4
# 0  10.0  20.0  56.0   1
# 1  56.0  56.0  56.0   2
# 2  30.0  56.0  56.0   3

# %%
df9['K1'].fillna(value=56)
# Out:
# 0    10.0
# 1    56.0
# 2    30.0
# Name: K1, dtype: float64

# %%
df9['K1'].fillna(value=56,inplace=True)

# %%
df9
# Out:
#      K1    K2  K3  K4
# 0  10.0  20.0 NaN   1
# 1  56.0   NaN NaN   2
# 2  30.0   NaN NaN   3

# %%
d={'K1':[10,20,30],'K2':[15,None,25],'K3':[100,None,50]}
df10 = pd.DataFrame(d)
df10.isnull().sum()
# Out:
# K1    0
# K2    1
# K3    1
# dtype: int64

# %%
df10.fillna(value=55)
# Out:
#    K1    K2     K3
# 0  10  15.0  100.0
# 1  20  55.0   55.0
# 2  30  25.0   50.0

# %%
np.mean([1,2,3,4,5])
# Out:
# 3.0

# %%
df10['K2'].fillna(value=np.mean(df10['K2']))
# Out:
# 0    15.0
# 1    20.0
# 2    25.0
# Name: K2, dtype: float64

# %%
df10['K2'].fillna(value=np.mean(df10['K2']),inplace=True)

# %%
df10
# Out:
#    K1    K2     K3
# 0  10  15.0  100.0
# 1  20  20.0    NaN
# 2  30  25.0   50.0

# %%
df10['K3'].fillna(value=np.mean(df10['K3']),inplace=True)

# %%
df10.isnull()
# Out:
#       K1     K2     K3
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False

# %%
df10.isnull().sum()
# Out:
# K1    0
# K2    0
# K3    0
# dtype: int64

# %%
df6 = pd.read_excel('E:\\mycourse.xlsx',sheet_name=['One','products'])
df6['products']
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0         NaN    product      price
# 1         NaN      prodA       1000
# 2         NaN      prodB        NaN
# 3         NaN      prodC       3000
# 4         NaN      prodD       3000
# 5         NaN      prodA        NaN
# 6         NaN      prodB       6000
# 7         NaN      prodE       5412
# 8         NaN      prodB       8000
# 9         NaN      prodD       3000

# %%
pd.read_excel('E://mycourse.xlsx',sheet_name='products')
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0         NaN    product      price
# 1         NaN      prodA       1000
# 2         NaN      prodB        NaN
# 3         NaN      prodC       3000
# 4         NaN      prodD       3000
# 5         NaN      prodA        NaN
# 6         NaN      prodB       6000
# 7         NaN      prodE       5412
# 8         NaN      prodB       8000
# 9         NaN      prodD       3000

# %%
pd.read_excel('E://mycourse.xlsx',sheet_name='products',header=1)
# Out:
#    Unnamed: 0 product   price
# 0         NaN   prodA  1000.0
# 1         NaN   prodB     NaN
# 2         NaN   prodC  3000.0
# 3         NaN   prodD  3000.0
# 4         NaN   prodA     NaN
# 5         NaN   prodB  6000.0
# 6         NaN   prodE  5412.0
# 7         NaN   prodB  8000.0
# 8         NaN   prodD  3000.0

# %%
df11 = pd.read_excel('E://mycourse.xlsx',sheet_name='products',header=1)
df11
# Out:
#    Unnamed: 0 product   price
# 0         NaN   prodA  1000.0
# 1         NaN   prodB     NaN
# 2         NaN   prodC  3000.0
# 3         NaN   prodD  3000.0
# 4         NaN   prodA     NaN
# 5         NaN   prodB  6000.0
# 6         NaN   prodE  5412.0
# 7         NaN   prodB  8000.0
# 8         NaN   prodD  3000.0

# %%
df11.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# dtype: bool

# %%
df11.duplicated().sum()
# Out:
# 1

# %%
df11.duplicated().any()
# Out:
# True

# %%
df11.drop_duplicates(inplace=True)

# %%
df11.duplicated().any()
# Out:
# False

# %%
df11.duplicated().sum()
# Out:
# 0

# %%
df11.isnull()
# Out:
#    Unnamed: 0  product  price
# 0        True    False  False
# 1        True    False   True
# 2        True    False  False
# 3        True    False  False
# 4        True    False   True
# 5        True    False  False
# 6        True    False  False
# 7        True    False  False

# %%
df11.isnull().sum()
# Out:
# Unnamed: 0    8
# product       0
# price         2
# dtype: int64

# %%
df11.rename(columns={'Unnamed: 0':'Key1'},inplace=True)

# %%
df11.columns
# Out:
# Index(['Key1', 'product', 'price'], dtype='object')

# %%
df11.isnull().sum()
# Out:
# Key1       8
# product    0
# price      2
# dtype: int64

# %%
df11
# Out:
#    Key1 product   price
# 0   NaN   prodA  1000.0
# 1   NaN   prodB     NaN
# 2   NaN   prodC  3000.0
# 3   NaN   prodD  3000.0
# 4   NaN   prodA     NaN
# 5   NaN   prodB  6000.0
# 6   NaN   prodE  5412.0
# 7   NaN   prodB  8000.0

# %%
df11['Key1'].fillna(value='abc',inplace=True)
df11['price'].fillna(value=np.mean(df11['price']),inplace=True)

# %%
df11
# Out:
#   Key1 product   price
# 0  abc   prodA  1000.0
# 1  abc   prodB  4402.0
# 2  abc   prodC  3000.0
# 3  abc   prodD  3000.0
# 4  abc   prodA  4402.0
# 5  abc   prodB  6000.0
# 6  abc   prodE  5412.0
# 7  abc   prodB  8000.0

# %%
#df11.at['4','price'] = 5000 - add new record
#   Vs
df11.at[4,'price']=555   ## To modify particular cell value

# %%
df11
# Out:
#   Key1 product   price
# 0  abc   prodA  1000.0
# 1  abc   prodB  4402.0
# 2  abc   prodC  3000.0
# 3  abc   prodD  3000.0
# 4  abc   prodA   555.0
# 5  abc   prodB  6000.0
# 6  abc   prodE  5412.0
# 7  abc   prodB  8000.0
# 4  NaN     NaN  5000.0

# %%
df11['Key1'].replace('abc','XYZ')
# Out:
# 0    XYZ
# 1    XYZ
# 2    XYZ
# 3    XYZ
# 4    XYZ
# 5    XYZ
# 6    XYZ
# 7    XYZ
# 4    NaN
# Name: Key1, dtype: object

# %%
df11['Key1'].replace('abc','XYZ',inplace=True)

# %%
df11
# Out:
#   Key1 product   price
# 0  XYZ   prodA  1000.0
# 1  XYZ   prodB  4402.0
# 2  XYZ   prodC  3000.0
# 3  XYZ   prodD  3000.0
# 4  XYZ   prodA   555.0
# 5  XYZ   prodB  6000.0
# 6  XYZ   prodE  5412.0
# 7  XYZ   prodB  8000.0
# 4  NaN     NaN  5000.0

# %%
df11['product'].replace('prodA','producA',inplace=True)

# %%
df11
# Out:
#   Key1  product   price
# 0  XYZ  producA  1000.0
# 1  XYZ    prodB  4402.0
# 2  XYZ    prodC  3000.0
# 3  XYZ    prodD  3000.0
# 4  XYZ  producA   555.0
# 5  XYZ    prodB  6000.0
# 6  XYZ    prodE  5412.0
# 7  XYZ    prodB  8000.0
# 4  NaN      NaN  5000.0

# %%
df11['Key1'].fillna(value='XYZ',inplace=True)
df11['product'].fillna(value='prodAB',inplace=True)

# %%
df11
# Out:
#   Key1  product   price
# 0  XYZ  producA  1000.0
# 1  XYZ    prodB  4402.0
# 2  XYZ    prodC  3000.0
# 3  XYZ    prodD  3000.0
# 4  XYZ  producA   555.0
# 5  XYZ    prodB  6000.0
# 6  XYZ    prodE  5412.0
# 7  XYZ    prodB  8000.0
# 4  XYZ   prodAB  5000.0

# %%
df11['product'].value_counts()
# Out:
# product
# prodB      3
# producA    2
# prodC      1
# prodD      1
# prodE      1
# prodAB     1
# Name: count, dtype: int64

# %%
df12 = pd.read_csv('E:\\emp.csv')
df12.head()
# Out:
#    eid  ename  edept     eplace  ecost
# 0  101    raj  sales       pune   1000
# 1  102    leo   prod     bglore   2000
# 2  103   paul     HR    chennai   3000
# 3  104    anu     hr  hyderabad   4000
# 4  456  kumar  sales     bglore   3000

# %%
df12.tail()
# Out:
#    eid  ename  edept     eplace  ecost
# 5  105   zion     Hr     mumbai   5000
# 6  106   bibu  sales     bglore   1450
# 7  107  theeb  sales      noida   4590
# 8  108   bibu  sales     bglore   5000
# 9  113  kumar   prod  hyderabad   5423

# %%
df12.sample(n=5) # random sample - take any 5 items
# Out:
#    eid  ename  edept  eplace  ecost
# 6  106   bibu  sales  bglore   1450
# 5  105   zion     Hr  mumbai   5000
# 0  101    raj  sales    pune   1000
# 8  108   bibu  sales  bglore   5000
# 4  456  kumar  sales  bglore   3000

# %%
df12[df12['edept'] == 'sales']
# Out:
#    eid  ename  edept  eplace  ecost
# 0  101    raj  sales    pune   1000
# 4  456  kumar  sales  bglore   3000
# 6  106   bibu  sales  bglore   1450
# 7  107  theeb  sales   noida   4590
# 8  108   bibu  sales  bglore   5000

# %%
df12.query('edept == "sales"')
# Out:
#    eid  ename  edept  eplace  ecost
# 0  101    raj  sales    pune   1000
# 4  456  kumar  sales  bglore   3000
# 6  106   bibu  sales  bglore   1450
# 7  107  theeb  sales   noida   4590
# 8  108   bibu  sales  bglore   5000

# %%
df12.filter(items=['edept'])
# Out:
#    edept
# 0  sales
# 1   prod
# 2     HR
# 3     hr
# 4  sales
# 5     Hr
# 6  sales
# 7  sales
# 8  sales
# 9   prod

# %%
df12['edept']
# Out:
# 0    sales
# 1     prod
# 2       HR
# 3       hr
# 4    sales
# 5       Hr
# 6    sales
# 7    sales
# 8    sales
# 9     prod
# Name: edept, dtype: object

# %%
df12['ecost'].aggregate('sum')
# Out:
# 34463

# %%
df12['ecost'].aggregate('mean')
# Out:
# 3446.3

# %%
df12['ecost'].aggregate('max')
# Out:
# 5423

# %%
df12['ecost'].aggregate('min')
# Out:
# 1000

# %%
# Load this data
#            |->used_cars_data.csv

1. Check no.of rows and cols
2. using info() 
3. get list of columns & index
     |->3.1 select sample -> 20 items 
4. check duplicate item is exists <or> not
5.           |->no.of duplicate items 
6.           |->drop duplicate items
7. check NaN value is exists ->replace NaN value
8. select few cols from dataset
                        -> rename 
9. drop some unwanted Cols.
10.  - display 1st 7lines & last 7lines
11.  - use query()
---------------------------------------------------

# %%
df = pd.read_csv('C:\\users\\Raja\\downloads\\used_cars_data.csv')
df.shape
# Out:
# (7253, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
new_df = df.sample(n=20)
new_df.shape
# Out:
# (20, 14)

# %%
new_df.index
# Out:
# Index([  94, 5320, 3139, 3883, 5109, 5407,  176, 6604, 3731, 3874, 2419, 1405,
#        3051, 5944, 4744, 4606,  732, 1672, 3820, 3202],
#       dtype='int64')

# %%
new_df.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 94 to 3202
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              20 non-null     int64
#  1   Name               20 non-null     object
#  2   Location           20 non-null     object
#  3   Year               20 non-null     int64
#  4   Kilometers_Driven  20 non-null     int64
#  5   Fuel_Type          20 non-null     object
#  6   Transmission       20 non-null     object
#  7   Owner_Type         20 non-null     object
#  8   Mileage            20 non-null     object
#  9   Engine             20 non-null     object
#  10  Power              20 non-null     object
#  11  Seats              20 non-null     float64
#  12  New_Price          3 non-null      object
#  13  Price              19 non-null     float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 2.3+ KB

# %%
new_df.duplicated().sum()
# Out:
# 0

# %%
new_df.duplicated().any()
# Out:
# False

# %%
new_df.isna().sum()
# Out:
# S.No.                 0
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               0
# Engine                0
# Power                 0
# Seats                 0
# New_Price            17
# Price                 1
# dtype: int64

# %%
new_df.isnull().sum()/len(new_df)*100
# Out:
# S.No.                 0.0
# Name                  0.0
# Location              0.0
# Year                  0.0
# Kilometers_Driven     0.0
# Fuel_Type             0.0
# Transmission          0.0
# Owner_Type            0.0
# Mileage               0.0
# Engine                0.0
# Power                 0.0
# Seats                 0.0
# New_Price            85.0
# Price                 5.0
# dtype: float64

# %%
new_df.fillna(value=new_df.isnull().sum()/len(new_df)*100,inplace=True)

# %%
new_df.isna().sum()
# Out:
# S.No.                0
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# New_Price            0
# Price                0
# dtype: int64

# %%
new_df.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
new_df.drop(['S.No.','Location','Owner_Type','Power','Seats'],axis=1,inplace=True)

# %%
new_df.shape
# Out:
# (20, 9)

# %%
new_df.columns
# Out:
# Index(['Name', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Mileage', 'Engine', 'New_Price', 'Price'],
#       dtype='object')

# %%
new_df.rename(columns={'Kilometers_Driven':'Km'},inplace=True)

# %%
new_df.columns
# Out:
# Index(['Name', 'Year', 'Km', 'Fuel_Type', 'Transmission', 'Mileage', 'Engine',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
new_df.rename(columns={'Transmission':'Trans','Mileage':'Mile'},inplace=True)

# %%
new_df.columns
# Out:
# Index(['Name', 'Year', 'Km', 'Fuel_Type', 'Trans', 'Mile', 'Engine',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 94 to 3202
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       20 non-null     object
#  1   Year       20 non-null     int64
#  2   Km         20 non-null     int64
#  3   Fuel_Type  20 non-null     object
#  4   Trans      20 non-null     object
#  5   Mile       20 non-null     object
#  6   Engine     20 non-null     object
#  7   New_Price  20 non-null     object
#  8   Price      20 non-null     float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 1.6+ KB

# %%
new_df.isna().sum()
# Out:
# Name         0
# Year         0
# Km           0
# Fuel_Type    0
# Trans        0
# Mile         0
# Engine       0
# New_Price    0
# Price        0
# dtype: int64

# %%
new_df.duplicated().sum()
# Out:
# 0

# %%
new_df.head(7)
# Out:
#                                   Name  Year     Km Fuel_Type      Trans  \
# 94              Mahindra XUV500 W8 2WD  2014  58000    Diesel     Manual
# 5320  Volkswagen Polo 1.2 MPI Highline  2016   7523    Petrol     Manual
# 3139                Hyundai i10 Sportz  2013  32776    Petrol     Manual
# 3883                 Maruti Ertiga ZXI  2013  82543    Petrol     Manual
# 5109      Hyundai Grand i10 CRDi Magna  2015  63776    Diesel     Manual
# 5407            Nissan Micra Diesel XV  2011  39010    Diesel     Manual
# 176           Mini Countryman Cooper D  2017   8525    Diesel  Automatic
#
#             Mile   Engine New_Price  Price
# 94     15.1 kmpl  2179 CC      85.0   8.10
# 5320   16.2 kmpl  1199 CC      85.0   6.15
# 3139  20.36 kmpl  1197 CC      85.0   4.64
# 3883  16.02 kmpl  1373 CC      85.0   5.50
# 5109   24.0 kmpl  1120 CC      85.0   3.96
# 5407  23.08 kmpl  1461 CC      85.0   2.60
# 176    16.6 kmpl  1998 CC      85.0  23.00

# %%
new_df.tail(7)
# Out:
#                                           Name  Year     Km Fuel_Type   Trans  \
# 5944  Ford EcoSport 1.0 Ecoboost Titanium Plus  2015  64000    Petrol  Manual
# 4744      Hyundai Santro Xing XL eRLX Euro III  2005  45000    Petrol  Manual
# 4606                   Maruti Zen LXi - BS III  2006  80000    Petrol  Manual
# 732                        Honda City i-VTEC V  2014  55818    Petrol  Manual
# 1672                       Nissan Micra Diesel  2011  80000    Diesel  Manual
# 3820                       Maruti Alto K10 VXI  2011  28300    Petrol  Manual
# 3202                          Maruti Swift VDI  2014  50000    Diesel  Manual
#
#             Mile   Engine   New_Price  Price
# 5944  18.88 kmpl   999 CC        85.0   6.00
# 4744   17.0 kmpl  1086 CC        85.0   0.95
# 4606   17.3 kmpl   993 CC        85.0   1.20
# 732    17.4 kmpl  1497 CC  11.85 Lakh   5.70
# 1672   19.5 kmpl  1461 CC        85.0   2.10
# 3820  24.07 kmpl   998 CC    4.5 Lakh   2.15
# ...

# %%
new_df.query('Km >30000 and Fuel_Type == "Diesel"')
# Out:
#                                             Name  Year     Km Fuel_Type  \
# 94                        Mahindra XUV500 W8 2WD  2014  58000    Diesel
# 5109                Hyundai Grand i10 CRDi Magna  2015  63776    Diesel
# 5407                      Nissan Micra Diesel XV  2011  39010    Diesel
# 6604            Nissan Sunny 2011-2014 Diesel XL  2012  45000    Diesel
# 3731                     Nissan Terrano XV D Pre  2013  60000    Diesel
# 3874  Ford Ecosport 1.5 DV5 MT Titanium Optional  2015  45000    Diesel
# 1405                           Maruti Ertiga ZDI  2013  70000    Diesel
# 1672                         Nissan Micra Diesel  2011  80000    Diesel
# 3202                            Maruti Swift VDI  2014  50000    Diesel
#
#        Trans        Mile   Engine   New_Price  Price
# 94    Manual   15.1 kmpl  2179 CC        85.0   8.10
# 5109  Manual   24.0 kmpl  1120 CC        85.0   3.96
# 5407  Manual  23.08 kmpl  1461 CC        85.0   2.60
# ...

# %%
new_df.query('Km >30000 and Km <50000 and Fuel_Type == "Diesel"')
# Out:
#                                             Name  Year     Km Fuel_Type  \
# 5407                      Nissan Micra Diesel XV  2011  39010    Diesel
# 6604            Nissan Sunny 2011-2014 Diesel XL  2012  45000    Diesel
# 3874  Ford Ecosport 1.5 DV5 MT Titanium Optional  2015  45000    Diesel
#
#        Trans        Mile   Engine New_Price  Price
# 5407  Manual  23.08 kmpl  1461 CC      85.0    2.6
# 6604  Manual  21.64 kmpl  1461 CC      85.0    5.0
# 3874  Manual   22.7 kmpl  1498 CC      85.0    8.9

# %%
new_df['Mile'].replace('[a-zA-Z\s]', value='',regex=True)
# Out:
# 94       15.1
# 5320     16.2
# 3139    20.36
# 3883    16.02
# 5109     24.0
# 5407    23.08
# 176      16.6
# 6604    21.64
# 3731    19.64
# 3874     22.7
# 2419     18.0
# 1405    20.77
# 3051     11.3
# 5944    18.88
# 4744     17.0
# 4606     17.3
# 732      17.4
# 1672     19.5
# 3820    24.07
# 3202     22.9
# Name: Mile, dtype: object

# %%
# delete all the alpha and / chars - this is regx substitute logic
new_df['Mile'].replace('[a-zA-Z\s\/]', value='',regex=True,inplace=True)

# %%
new_df.query('Km >30000 and Km <50000 and Fuel_Type == "Diesel"')
# Out:
#                                             Name  Year     Km Fuel_Type  \
# 5407                      Nissan Micra Diesel XV  2011  39010    Diesel
# 6604            Nissan Sunny 2011-2014 Diesel XL  2012  45000    Diesel
# 3874  Ford Ecosport 1.5 DV5 MT Titanium Optional  2015  45000    Diesel
#
#        Trans   Mile   Engine New_Price  Price
# 5407  Manual  23.08  1461 CC      85.0    2.6
# 6604  Manual  21.64  1461 CC      85.0    5.0
# 3874  Manual   22.7  1498 CC      85.0    8.9

# %%
new_df['Mile']
# Out:
# 94       15.1
# 5320     16.2
# 3139    20.36
# 3883    16.02
# 5109     24.0
# 5407    23.08
# 176      16.6
# 6604    21.64
# 3731    19.64
# 3874     22.7
# 2419     18.0
# 1405    20.77
# 3051     11.3
# 5944    18.88
# 4744     17.0
# 4606     17.3
# 732      17.4
# 1672     19.5
# 3820    24.07
# 3202     22.9
# Name: Mile, dtype: object

# %%
d={'K1':[10,20,30],'K2':[15,25,35],'K3':[100,200,300]}
df = pd.DataFrame(d)
df
# Out:
#    K1  K2   K3
# 0  10  15  100
# 1  20  25  200
# 2  30  35  300

# %%
df = pd.DataFrame(d,index=['i1','i2','i3'])
df
# Out:
#     K1  K2   K3
# i1  10  15  100
# i2  20  25  200
# i3  30  35  300

# %%
pd.read_csv('E:\\emp.csv',index_col='edept')
# Out:
#        eid  ename     eplace  ecost
# edept
# sales  101    raj       pune   1000
# prod   102    leo     bglore   2000
# HR     103   paul    chennai   3000
# hr     104    anu  hyderabad   4000
# sales  456  kumar     bglore   3000
# Hr     105   zion     mumbai   5000
# sales  106   bibu     bglore   1450
# sales  107  theeb      noida   4590
# sales  108   bibu     bglore   5000
# prod   113  kumar  hyderabad   5423

# %%
df = pd.read_csv('E:\\emp.csv')
df
# Out:
#    eid  ename  edept     eplace  ecost
# 0  101    raj  sales       pune   1000
# 1  102    leo   prod     bglore   2000
# 2  103   paul     HR    chennai   3000
# 3  104    anu     hr  hyderabad   4000
# 4  456  kumar  sales     bglore   3000
# 5  105   zion     Hr     mumbai   5000
# 6  106   bibu  sales     bglore   1450
# 7  107  theeb  sales      noida   4590
# 8  108   bibu  sales     bglore   5000
# 9  113  kumar   prod  hyderabad   5423

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df['eplace']
# Out:
# 0         pune
# 1       bglore
# 2      chennai
# 3    hyderabad
# 4       bglore
# 5       mumbai
# 6       bglore
# 7        noida
# 8       bglore
# 9    hyderabad
# Name: eplace, dtype: object

# %%
df.index = df['eplace'] # set the index

# %%
df
# Out:
#            eid  ename  edept     eplace  ecost
# eplace
# pune       101    raj  sales       pune   1000
# bglore     102    leo   prod     bglore   2000
# chennai    103   paul     HR    chennai   3000
# hyderabad  104    anu     hr  hyderabad   4000
# bglore     456  kumar  sales     bglore   3000
# mumbai     105   zion     Hr     mumbai   5000
# bglore     106   bibu  sales     bglore   1450
# noida      107  theeb  sales      noida   4590
# bglore     108   bibu  sales     bglore   5000
# hyderabad  113  kumar   prod  hyderabad   5423

# %%
new_df.index
# Out:
# Index([  94, 5320, 3139, 3883, 5109, 5407,  176, 6604, 3731, 3874, 2419, 1405,
#        3051, 5944, 4744, 4606,  732, 1672, 3820, 3202],
#       dtype='int64')

# %%
new_df['Year']
# Out:
# 94      2014
# 5320    2016
# 3139    2013
# 3883    2013
# 5109    2015
# 5407    2011
# 176     2017
# 6604    2012
# 3731    2013
# 3874    2015
# 2419    2014
# 1405    2013
# 3051    2016
# 5944    2015
# 4744    2005
# 4606    2006
# 732     2014
# 1672    2011
# 3820    2011
# 3202    2014
# Name: Year, dtype: int64

# %%
new_df.index = new_df['Year']

# %%
new_df
# Out:
#                                                 Name  Year     Km Fuel_Type  \
# Year
# 2014                          Mahindra XUV500 W8 2WD  2014  58000    Diesel
# 2016                Volkswagen Polo 1.2 MPI Highline  2016   7523    Petrol
# 2013                              Hyundai i10 Sportz  2013  32776    Petrol
# 2013                               Maruti Ertiga ZXI  2013  82543    Petrol
# 2015                    Hyundai Grand i10 CRDi Magna  2015  63776    Diesel
# 2011                          Nissan Micra Diesel XV  2011  39010    Diesel
# 2017                        Mini Countryman Cooper D  2017   8525    Diesel
# 2012                Nissan Sunny 2011-2014 Diesel XL  2012  45000    Diesel
# 2013                         Nissan Terrano XV D Pre  2013  60000    Diesel
# 2015      Ford Ecosport 1.5 DV5 MT Titanium Optional  2015  45000    Diesel
# 2014                           Honda Amaze S i-Vtech  2014  69876    Petrol
# ...

# %%
new_df.loc[2016]
# Out:
#                                                 Name  Year     Km Fuel_Type  \
# Year
# 2016                Volkswagen Polo 1.2 MPI Highline  2016   7523    Petrol
# 2016  Mercedes-Benz GL-Class 350 CDI Blue Efficiency  2016  16000    Diesel
#
#           Trans  Mile   Engine New_Price  Price
# Year
# 2016     Manual  16.2  1199 CC      85.0   6.15
# 2016  Automatic  11.3  2987 CC      85.0  56.00

# %%
new_df.to_excel('E:\\test1.xlsx')
# Write to Excel file

# %%
import requests
import bs4

# %%
def download_url(url):
    r=requests.get(url)
    if(r.status_code != 200):
        print('url download is failed')
        return False
    if('text/html' in r.headers['Content-Type']):
        ol_web = r.text
        webparsing(ol_web)
    else:
        return 'Given url is not a webpage content'

# %%
Linux_rpm=[]
def webparsing(webpage):
    print(webpage)
    ol_obj = bs4.BeautifulSoup(webpage)
    for var in ol_obj.find_all('a'):
        if(re.search('rpm$',var.get('href'))):
            Linux_rpm.append(var.string)

# %%
ol_rpm={}

# %%
ol7_url='https://yum.oracle.com/repo/OracleLinux/OL7/latest/x86_64/index.html'
ol8_url='https://yum.oracle.com/repo/OracleLinux/OL8/baseos/latest/x86_64/index.html'
ol9_url='https://yum.oracle.com/repo/OracleLinux/OL9/baseos/latest/x86_64/index.html'

# %%
download_url(ol7_url)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
ol_rpm['OL7']=Linux_rpm

# %%
download_url(ol8_url)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
ol_rpm['OL8']=Linux_rpm

# %%
download_url(ol9_url)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
ol_rpm['OL9']=Linux_rpm

# %%
ol_df = pd.DataFrame(ol_rpm)
ol_df.to_excel('E:\\ol_rpm.xlsx') # write ol rpm df ->excel

# %%
new_df[new_df.axes[1]]
# Out:
#                                                 Name  Year     Km Fuel_Type  \
# Year
# 2014                          Mahindra XUV500 W8 2WD  2014  58000    Diesel
# 2016                Volkswagen Polo 1.2 MPI Highline  2016   7523    Petrol
# 2013                              Hyundai i10 Sportz  2013  32776    Petrol
# 2013                               Maruti Ertiga ZXI  2013  82543    Petrol
# 2015                    Hyundai Grand i10 CRDi Magna  2015  63776    Diesel
# 2011                          Nissan Micra Diesel XV  2011  39010    Diesel
# 2017                        Mini Countryman Cooper D  2017   8525    Diesel
# 2012                Nissan Sunny 2011-2014 Diesel XL  2012  45000    Diesel
# 2013                         Nissan Terrano XV D Pre  2013  60000    Diesel
# 2015      Ford Ecosport 1.5 DV5 MT Titanium Optional  2015  45000    Diesel
# 2014                           Honda Amaze S i-Vtech  2014  69876    Petrol
# ...

# %%
# matplotlib -> Visualization

import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.7.2'

# %%
matplotlib.__file__
# Out:
# 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\__init__.py'

# %%
matplotlib/ 1st 
        |--->pyplot.py 2nd
               |--------->plot(),scatter(),....
                          ..........................
            
            
import matplotlib.pyplot
matplotlib.pyplot.plot()
Vs

import matplotlib.pyplot as plt
plt.plot()
plt.scatter()
...

# %%
import matplotlib.pyplot
print(matplotlib.pyplot)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
import matplotlib.pyplot as plt
#help(plt.plot)

plt.plot([10,20,30,40],[15,25,5,65])

# %%
plt.plot([10,20,30,40],[15,25,5,65],marker='o')

# %%
plt.plot([1, 2, 3], [10, 5, 13], 'go-')

# %%
plt.plot([1, 2, 3], [10, 5, 13], 'ro-')

# %%
plt.plot([1, 2, 3], [10, 5, 13], 'r+--')

# %%
plt.plot([1,2,3],[15,25,35],marker='o')

# %%
plt.scatter([1,2,3],[15,5,35])

# %%
plt.bar([1,2,3],[15,5,35])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh([1,2,3],[15,5,35])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie([1,2,3])
# Out:
# ([<matplotlib.patches.Wedge at 0x1c29894c950>,
# ...
#  [Text(0.9526279355804298, 0.5500000148652441, ''),
#   Text(-0.5500000594609755, 0.9526279098330699, ''),
#   Text(1.0298943251329445e-07, -1.0999999999999954, '')])

# %%
plt.imshow([[10,20,30]])

# %%
plt.boxplot([10,20,30])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c298a07210>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c2989e1f90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c298a06450>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c298e16090>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c298e16a90>],
#  'means': []}

# %%
plt.plot([10,5,20],[100,150,200],marker='d',ms=10)

# %%
plt.plot([10,5,20],[100,150,200],marker='^',ms=10)

# %%
plt.plot([10,5,20],[100,150,200],marker='v',ms=10,color='r')

# %%
plt.plot([10,5,20],[100,150,200],marker='v',ms=10,color='r')

# %%
plt.bar([10,5,20],[100,150,200],width=0.5,color='g')
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh([10,5,20],[100,150,200],height=0.5,color='b')
# Out:
# <BarContainer object of 3 artists>

# %%
plt.scatter([10,5,15,28,29,31,35],[100,150,50,60,120,135,45],marker='d')

# %%
plt.scatter([10,5,15,28,29,31,35],[100,150,50,60,120,135,45],marker='d')
plt.scatter([1,5,7,8,9,11,15],[10,15,45,54,12,35,185],marker='o')

# %%
plt.scatter([10,5,15,28,29,31,35],[100,150,50,60,120,135,45],marker='d')
plt.scatter([1,5,7,8,9,11,15],[10,15,45,54,12,35,185],marker='o')
plt.plot([14,15,25,38,49,51,65],[200,350,420,160,20,235,145],marker='^',color='g')

# %%
## Task
   |
load home.csv file 
  |
  |-> info about home.csv 
      - duplicated ->drop duplicates 
      - replace null values
      - select any two cols - X , Y 
                            |
                           matplotlib - Visualization

# %%
pd.read_csv('E:\\home.csv')
# Out:
#    month  water  telephone    eb  gas  provision  fuel  internet  academic  \
# 0    jan    200       1300   505  930       8900  1600      1700     35000
# 1    feb    200       1300   125  930       4000  1800      1710     55000
# 2    mar    200       1350   505  930       5000  1600      1700       500
# 3    apr    600       1365   125  930       3000  1800      1710     15000
# 4    may    700       1234    65  850      10000  1800      1700      6000
# 5    jun    800       1700    88  890       7000  1600      1710       200
# 6    jul    200       1783     0  930       8900  1700      1700       100
# 7    aug    150       1100  1235  780       6000  1960      1710       500
# 8    sep    200       1230  1500  760       4900  1650      1700       600
# 9    oct    200       1323    70  789       4600  1500      1710       700
# 10   nov    200       1231   656  880       6900  1900      1800       500
# ...

# %%
home_df = pd.read_csv('E:\\home.csv')
home_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   month      12 non-null     object
#  1   water      12 non-null     int64
#  2   telephone  12 non-null     int64
#  3   eb         12 non-null     int64
#  4   gas        12 non-null     int64
#  5   provision  12 non-null     int64
#  6   fuel       12 non-null     int64
#  7   internet   12 non-null     int64
#  8   academic   12 non-null     int64
#  9   external   12 non-null     int64
# dtypes: int64(9), object(1)
# memory usage: 1.1+ KB

# %%
home_df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
home_df.columns
# Out:
# Index(['month', 'water', 'telephone', 'eb', 'gas', 'provision', 'fuel',
#        'internet', 'academic', 'external'],
#       dtype='object')

# %%
home_df.head(3)
# Out:
#   month  water  telephone   eb  gas  provision  fuel  internet  academic  \
# 0   jan    200       1300  505  930       8900  1600      1700     35000
# 1   feb    200       1300  125  930       4000  1800      1710     55000
# 2   mar    200       1350  505  930       5000  1600      1700       500
#
#    external
# 0      5000
# 1      9000
# 2      5000

# %%
home_df.duplicated().any()
# Out:
# False

# %%
home_df.isnull().any()
# Out:
# month        False
# water        False
# telephone    False
# eb           False
# gas          False
# provision    False
# fuel         False
# internet     False
# academic     False
# external     False
# dtype: bool

# %%
home_df.rename(columns={'telephone':'tele','provision':'pro','internet':'net'},inplace=True)

# %%
home_df.columns
# Out:
# Index(['month', 'water', 'tele', 'eb', 'gas', 'pro', 'fuel', 'net', 'academic',
#        'external'],
#       dtype='object')

# %%
X = home_df['month']
Y = home_df['water']

# %%
plt.plot(X,Y,marker='o',color='r')

# %%
plt.plot(X,Y,marker='o',color='r')
plt.xlabel('MONTH')
plt.ylabel('AMOUNT')
plt.title('Water Bill - Report 2023')
# Out:
# Text(0.5, 1.0, 'Water Bill - Report 2023')

# %%
X = home_df['month']
Y = home_df['fuel']
plt.plot(X,Y,marker='*',color='black')
plt.xlabel('MONTH')
plt.ylabel('AMOUNT')
plt.title('Fuel Bill - Report 2023')
# Out:
# Text(0.5, 1.0, 'Fuel Bill - Report 2023')

# %%
X = home_df['month']
Y = home_df['fuel']

plt.xlabel('MONTH')
plt.ylabel('AMOUNT')
plt.title('Fuel Bill - Report 2023')
plt.bar(X,Y,width=0.3)
# Out:
# <BarContainer object of 12 artists>

# %%
X1 = home_df['month']
Y1 = home_df['fuel']

Y2 = home_df['water']
plt.xlabel('MONTH')
plt.ylabel('AMOUNT')
plt.title('Fuel & Water Bill - Report 2023')
plt.bar(X1,Y1,width=0.3)
plt.plot(X1,Y2,marker='o',color='r')

# %%
X1 = home_df['month']
Y1 = home_df['fuel']

Y2 = home_df['water']
plt.xlabel('MONTH')
plt.ylabel('AMOUNT')
plt.title('Fuel & Water Bill - Report 2023')
plt.bar(X1,Y1,width=0.3)
plt.bar(X1,Y2,color='r')
#plt.legend('Fuel','water')
# Out:
# <BarContainer object of 12 artists>

# %%
plt.pie([100,15,25,76],labels=['prodA','prodB','proC','prodD'])
plt.legend()

# %%
plt.pie(home_df['fuel'],labels=home_df['month'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1c2a5152490>,
# ...
#  [Text(1.0658165455689068, 0.27209390142295065, 'jan'),
#   Text(0.7811518427918157, 0.774468720157858, 'feb'),
#   Text(0.2812414266201684, 1.0634393541489109, 'mar'),
#   Text(-0.29616482095425317, 1.0593801955998305, 'apr'),
#   Text(-0.8154247489778412, 0.7382970125595963, 'may'),
#   Text(-1.0770456525246412, 0.22354566061046668, 'jun'),
#   Text(-1.0472717152449498, -0.3364847016550691, 'jul'),
#   Text(-0.6986211069955461, -0.8496637857766551, 'aug'),
#   Text(-0.13626393318651675, -1.0915274346128643, 'sep'),
#   Text(0.3956213890977273, -1.0263935485418763, 'oct'),
#   Text(0.8610085548318517, -0.6845905845878735, 'nov'),
#   Text(1.0807279031662669, -0.20500536411968395, 'dec')])

# %%
plt.scatter(home_df['month'],home_df['eb'],c='r')
plt.scatter(home_df['month'],home_df['water'])
plt.legend(title='expense')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print(home_df['eb'])
plt.boxplot(home_df['eb'])
# Out:
# 0      505
# 1      125
# 2      505
# 3      125
# 4       65
# 5       88
# 6        0
# 7     1235
# 8     1500
# 9       70
# 10     656
# 11     100
# Name: eb, dtype: int64
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c2a53c7150>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c2a53d4510>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c2a53c6850>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c2a53d5490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c2a5123010>],
#  'means': []}

# %%
#help(np.random.normal)
data_set = np.random.normal(10,3,20)
plt.boxplot(data_set)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c2a54f60d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c2a55f1050>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c2a55f1250>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c2a5600ad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c2a55e1510>],
#  'means': []}

# %%
data_set = np.random.normal(60,30,200)
plt.boxplot(data_set)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c2a5660b50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c2a5662310>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c2a5657e90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c2a56639d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c2a547f090>],
#  'means': []}

# %%
10 20 30 40 50 600 70
                |->outlier

# %%
plt.show()

# %%
X1 = np.array([10,20,30])
Y1 = np.array([150,25,110])
X2 = np.array([100,26,120])
Y2 = np.array([50,125,60])

plt.plot(X1,Y1,marker='+',c='r')
plt.plot(X2,Y2,marker='o',c='g')

# %%
X1 = np.array([10,20,30])
Y1 = np.array([150,25,110])

plt.subplot(1,2,1) # plt.subplot(121)
plt.plot(X1,Y1,marker='+',c='r')

X2 = np.array([100,26,120])
Y2 = np.array([50,125,60])
plt.subplot(1,2,2)
plt.plot(X2,Y2,marker='o',c='g')

# %%
L=list(range(1,13))
plt.subplot(2,2,1) # 221
plt.plot(L,home_df['eb'],marker='o',c='r')
plt.title('EB-Bill')

plt.subplot(2,2,2)
plt.plot(L,home_df['water'],marker='+')
plt.title('Water-Bill')

plt.subplot(2,2,3)
plt.scatter(L,home_df['fuel'])
plt.title('Fuel-Bill')
# Out:
# Text(0.5, 1.0, 'Fuel-Bill')

# %%
L=list(range(1,13))
plt.subplot(2,2,1) # 221
plt.plot(L,home_df['eb'],marker='o',c='r')
plt.title('EB-Bill')

plt.subplot(2,2,2)
plt.plot(L,home_df['water'],marker='+')
plt.title('Water-Bill')

plt.subplot(2,2,3)
plt.scatter(L,home_df['fuel'])
plt.title('Fuel-Bill')
# Out:
# Text(0.5, 1.0, 'Fuel-Bill')

# %%
plt.figure(figsize=(2,3))
plt.plot([1,2,3],[10,20,30])

# %%
# Histogram
http_request_duration = np.random.normal(150,20,450)

plt.hist(http_request_duration)
# Out:
# (array([  2.,  16.,  53.,  93., 106.,  95.,  54.,  22.,   6.,   3.]),
#  array([ 93.88618345, 106.06804907, 118.24991469, 130.43178031,
#         142.61364593, 154.79551155, 166.97737717, 179.15924279,
#         191.34110841, 203.52297403, 215.70483965]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(http_request_duration,bins=20)
# Out:
# (array([ 1.,  1.,  3., 13., 25., 28., 41., 52., 62., 44., 51., 44., 34.,
#         20., 15.,  7.,  3.,  3.,  1.,  2.]),
#  array([ 93.88618345,  99.97711626, 106.06804907, 112.15898188,
#         118.24991469, 124.3408475 , 130.43178031, 136.52271312,
#         142.61364593, 148.70457874, 154.79551155, 160.88644436,
#         166.97737717, 173.06830998, 179.15924279, 185.2501756 ,
#         191.34110841, 197.43204122, 203.52297403, 209.61390684,
#         215.70483965]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(http_request_duration,bins=20)
plt.xlabel('req-values')
plt.ylabel('density-req')
# Out:
# Text(0, 0.5, 'density-req')
